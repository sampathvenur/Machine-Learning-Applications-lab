# %% [markdown]
# a simple dataset you can create in csv format.the dataset contains fictional information about students,including their names,ages,grades and whether they passed.

# %%
import pandas as pd

#sample data
data={
    'Name':['Alice','Bob','Charlie','David','Eva','Frank'],
    'Age':[20,22,21,23,20,22],
    'Grade':[88,65,70,54,90,45],
    'Passed':['Yes','No','Yes','No','Yes','No']
}
#Create DataFrame
df=pd.DataFrame(data)
#save to CSV
df.to_csv('students.csv',index=False)
#Download the CSV file
from google.colab import files
files.download('students.csv')

# %%
import pandas as pd
from google.colab import drive
#Step 1:Mount Google Drive
drive.mount('/content/drive')

#step2: Define the path to your CSV file
#update the path according to where your file is located in google drive
file_path='/students.csv'#Change this to your file's path
#Step 3:Read the CSV file
df=pd.read_csv(file_path)
#Step 4:Display basic information
print("First few rows of the dataset:")
print(df.head())
#print("\nSummary statistics of the dataset:")
#printf(df.describe())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# First few rows of the dataset:
#       Name  Age  Grade Passed
# 0    Alice   20     88    Yes
# 1      Bob   22     65     No
# 2  Charlie   21     70    Yes
# 3    David   23     54     No
# 4      Eva   20     90    Yes

# %%
import numpy as np
import matplotlib.pyplot as plt
#Generate data
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)
#plot
plt.plot(x,y)
plt.title("Sine Wave")
plt.xlabel("X")
plt.ylabel("sin(x)")
plt.grid()
plt.show()

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
#Step 1:Load the CIFAR dataset
cifar10=tf.keras.datasets.cifar10
(X_train,Y_train),(X_test,Y_test)=cifar10.load_data()


#Step 2:Define class labels
class_names=['Airplane','Automobile','Bird','Cat','Deer','Dog','Frog']
#Step 3:Display a few images
def display_images(images,labels):
   plt.figure(figsize=(5,5))
   for i in range(79: #Display 9 images
     plt.subplot(3,3,i+1)
     plt.imshow(images[i])

     plt.title(class_names[labels[i][0]])
     plt.axis('off')
   plt.show()

display_images(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-464c9e6a38f8> in <cell line: 21>()
#      19    plt.show()
#      20
# ---> 21 display_images(X_train,Y_train)
#
# <ipython-input-23-464c9e6a38f8> in display_images(images, labels)
#      15      plt.imshow(images[i])
#      16
# ---> 17      plt.title(class_names[labels[i][0]])
#      18      plt.axis('off')
#      19    plt.show()
#
# IndexError: list index out of range

# %%
import csv
from google.colab import files
files.download('enjoysport.csv')
#Step 1:Create and write to the CSV file
def create_csv_file(filename):
  #define the data
  data=[
      ['Weather','Temperature','Humidity','Wind','Water','Forecast','Play'],
      ['Sunny','Warm','Normal','Strong','Warm','Same','Yes'],
      ['Sunny','Warm','High','Strong','Warm','Same','Yes'],
      ['Rainy','Cold','High','Strong','Warm','Change','No'],
      ['Sunny','Warm','High','Strong','Cool','Change','Yes'],


  ]
  #Create and write to the csv file
  with open(filename,'w',newline='') as csvfile:
    writer=csv.writer(csvfile)
    writer.writerows(data)
    print(f"CSV file '{filename}' has been  created.")

    #Step 2:Implement the FIND-S algorithm
def find_s_algorithm(filename,num_attributes):
      a=[]
      print("\nThe Given Training Data Set:\n")

      #Read the training data from the CSV file
      with open(filename,'r') as csvfile:
        reader=csv.reader(csvfile)
        for row in reader:
          a.append(row)
          print(row)
      print("\nThe initial value of hypothesis:")
      hypothesis=['0']*num_attributes
      print(hypothesis)

      #Initialise the hypothesis with the first positive instance
      for j in range(num_attributes):
        hypothesis[j]=a[1][j]#Start from the first positive instance
      print("\n Find S:Finding a Maximally Specific Hypothesis\n")
      #iterate through the data
      for i in range(1,len(a)):
       if a[i][num_attributes]=='yes':
        for j in range(num_attributes):
         if a[i][j]!=hypothesis[j]:
          hypothesis[j]='?'
         else:
          hypothesis[j]=a[i][j]
       print(f"For Training instance No:{i} the hypothesis is :{hypothesis}")
      print("\nThe Maximally Specific Hypothesis for the given Training Examples:\n")
      print(hypothesis)

#Main function to run the complete process
def main():
  filename='enjoysport.csv'
  create_csv_file(filename)
  num_attributes=6 #Number of attributes(excluding the label)
  find_s_algorithm(filename,num_attributes)

#run the main function
main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-db9f158e21ff> in <cell line: 3>()
#       1 import csv
#       2 from google.colab import files
# ----> 3 files.download('enjoysport.csv')
#       4 #Step 1:Create and write to the CSV file
#       5 def create_csv_file(filename):
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: enjoysport.csv

# %%
import pandas as pd
#step 1:create the dataset
data=[
     ['Sunny','Warm','Normal','Strong','Warm','Same','Yes'],
      ['Sunny','Warm','High','Strong','Warm','Same','Yes'],
      ['Rainy','Cold','High','Strong','Warm','Change','No'],
      ['Sunny','Warm','High','Strong','Cool','Change','Yes'],

]
#Step 2:Convert the data to a Dataframe
columns=['Outlook','Temperature','Humidity','Wind','Play','Activity','Target']
df=pd.DataFrame(data,columns=columns)

#Step 3:save the DataFrame to a CSV file
df.to_csv('dataset.csv',index=False)

#Step 4:Read the CSV file
df=pd.read_csv('dataset.csv')
concepts=df.values[:,:-1]
target=df.values[:,-1]

#Step5:Define the Candidate Elimination Algorithm
def learn(concepts,target):
  specific_h=concepts[0].copy()#Initialise specific hypothesis
  general_h=[["?" for _ in range (len(specific_h))] for _ in range (len(specific_h))]

  for i,h in enumerate(concepts):
    if target[i]=="Yes":
      for x in range (len(specific_h)):
        if h[x]!=specific_h[x]:
          specific_h[x]='?'
          general_h[x][x]='?'
    elif target[i]=="No":
      for x in range(len(specific_h)):
        if h[x]!=specific_h[x]:
          general_h[x][x]=specific_h[x]
        else:
          general_h[x][x]='?'

    #Remove all-? hypotheses from general hypotheses
  general_h=[gh for gh in general_h if gh != ['?' for _ in range (len(specific_h)) ]]
  return specific_h,general_h

#Step 6: Run the learning process
s_final,g_final=learn(concepts,target)

#Step 7: Print the final specific and geneeral hypothesis
print(f"Final S:{s_final}")

print(f"Final G:{g_final}")
# Out:
# Final S:['Sunny' 'Warm' '?' 'Strong' '?' '?']
# Final G:[['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]

# %%
import pandas as pd

# Step 1: Create the dataset
data = [
    ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'yes'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'yes'],
    ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'no'],
    ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'yes']
]

# Step 2: Convert the data to a DataFrame
columns = ['Outlook', 'Temperature', 'Humidity', 'Wind', 'Water', 'Forecast', 'PlaySport']
df = pd.DataFrame(data, columns=columns)

# Step 3: Save the DataFrame to a CSV file
df.to_csv('dataset.csv', index=False)

# Step 4: Read the CSV file
df = pd.read_csv('dataset.csv')
concepts = df.values[:, :-1]
target = df.values[:, -1]

# Step 5: Define the Candidate-Elimination algorithm
def learn(concepts, target):
    specific_h = concepts[0].copy()
    general_h = [["?" for _ in range(len(specific_h))] for _ in range(len(specific_h))]

    for i, h in enumerate(concepts):
        if target[i] == "yes":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    specific_h[x] = '?'
                    general_h[x][x] = '?'
        elif target[i] == "no":
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'

    # Remove all-? hypotheses from general hypothesis
    general_h = [gh for gh in general_h if gh != ['?' for _ in range(len(specific_h))]]
    return specific_h, general_h

# Step 6: Run the learning process
s_final, g_final = learn(concepts, target)
print(f"Final S: {s_final}")
print(f"Final G: {g_final}")
# Out:
# Final S: ['Sunny' 'Warm' '?' 'Strong' '?' '?']
# Final G: [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]

# %%
import csv
#from google.colab import files
#files.download('enjoysport.csv')

#step1: create and write to the csv file
def create_csv_file(filename):
    #define the data
    data=[
        ['Weather','Temperature','Humidity','Wind','Water','Forecast','Playsport'],
        ['Sunny','Warm','Normal','Strong','Warm','Same','yes'],
        ['Sunny','Warm','High','Strong','Warm','Same','yes'],
        ['Rainy','Cold','High','Strong','Warm','Change','no'],
        ['Sunny','Warm','High','Strong','Cool','Change','yes']
    ]

    #Create and write to the csv file
    with open(filename,'w',newline='') as csvfile:
            writer=csv.writer(csvfile)
            writer.writerows(data)
    print(f"CSV file '{filename}' has been created .")

#step2:implement the find -s algorithm
def find_s_algorithm(filename,num_attributes):
          a=[]
          print("The given training data Set:")

          with open(filename,'r') as csvfile:
            reader=csv.reader(csvfile)
            for row in reader:
              a.append(row)
              print(row)

          print('\n The initial value of hypothesis:')
          hypothesis=['0']*num_attributes
          print(hypothesis)

          #initialise the hypothesis with the first positive instance
          for j in range(num_attributes):
            hypothesis[j]=a[1][j]

          print("\n Find S:Finding a Maximally Specific Hypothesis\n")

          #iterate through the data
          for i in range(1,len(a)):
            if a[i][num_attributes]=='yes':
              for j in range(num_attributes):
                if a[i][j]!=hypothesis[j]:
                  hypothesis[j]='?'
                else:
                  hypothesis[j]=a[i][j]
            print(f"For Training example No:{i} the hypothesis is:{hypothesis}")
          print("\n The Maximally Specific Hypothesis for a given Training Examples:\n")
          print(hypothesis)

#main function to run the complete process
def main():
  filename='enjoysport.csv'
  create_csv_file(filename)
  num_attributes=6
  find_s_algorithm(filename,num_attributes)

#Run the main function
main()
# Out:
# CSV file 'enjoysport.csv' has been created .
# The given training data Set:
# ['Weather', 'Temperature', 'Humidity', 'Wind', 'Water', 'Forecast', 'Playsport']
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same', 'yes']
# ['Sunny', 'Warm', 'High', 'Strong', 'Warm', 'Same', 'yes']
# ['Rainy', 'Cold', 'High', 'Strong', 'Warm', 'Change', 'no']
# ['Sunny', 'Warm', 'High', 'Strong', 'Cool', 'Change', 'yes']
#
#  The initial value of hypothesis:
# ['0', '0', '0', '0', '0', '0']
#
#  Find S:Finding a Maximally Specific Hypothesis
#
# For Training example No:1 the hypothesis is:['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']
# For Training example No:2 the hypothesis is:['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# For Training example No:3 the hypothesis is:['Sunny', 'Warm', '?', 'Strong', 'Warm', 'Same']
# For Training example No:4 the hypothesis is:['Sunny', 'Warm', '?', 'Strong', '?', '?']
#
#  The Maximally Specific Hypothesis for a given Training Examples:
#
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

#step 1:load the CIFAR-10 dataset
cifar10=tf.keras.datasets.cifar10
(X_train,y_train ),(X_test,y_test)=cifar10.load_data()

 #step2:define class labels
class_names=['Airplane','Automobile','Bird','Cat','Deer','Dog','Frog','Horse','Ship','Truck']

 #step3:Display a few images
def display_images(images,labels):
   plt.figure(figsize=(5,5))
   for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(images[i])
    plt.title(class_names[labels[i][0]])
    plt.axis('off')
   plt.show()

  #display the first 9 images from the training set
display_images(X_train,y_train)
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
